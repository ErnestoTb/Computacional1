# %%
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime
import numpy as np

# %%
df = pd.read_csv("Mtry_CA_wl.csv", names = ("Date Time", "Water Level", "Sigma", "O", "F", "R", "L", "Quality"), header = 0)

# %%
df.head()
# Out:
#           Date Time  Water Level  Sigma  O  F  R  L Quality
# 0  2017-01-01 00:00        0.323  0.000  0  0  0  0       v
# 1  2017-01-01 00:06        0.324  0.063  0  0  0  0       v
# 2  2017-01-01 00:12        0.285  0.072  0  0  0  0       v
# 3  2017-01-01 00:18        0.272  0.050  0  0  0  0       v
# 4  2017-01-01 00:24        0.228  0.051  0  0  0  0       v

# %%
df['Date'] = pd.to_datetime(df["Date Time"], format = '%Y %m %d %H:%M:')

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date Time      0
# Water Level    0
# Sigma          0
# O              0
# F              0
# R              0
# L              0
# Quality        0
# Date           0
# dtype: int64

# %%
df.dtypes
# Out:
# Date Time              object
# Water Level           float64
# Sigma                 float64
# O                       int64
# F                       int64
# R                       int64
# L                       int64
# Quality                object
# Date           datetime64[ns]
# dtype: object

# %%
tides = plt.plot(df[u'Date'], df[u'Water Level'], 'g', label ="Altura")
plt.xlim(pd.Timestamp('2017-01-01 00:00:00'), pd.Timestamp('2017-01-31 23:54:00')) 
plt.ylabel('Altura de marea [m]')
plt.xlabel('Día')
plt.title('Marea en Monterey, CA,  durante Enero 2017')
plt.grid(True)

fig = plt.gcf()
fig.set_size_inches(20, 8)
plt.show()
