# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pylab as plb
from pylab import figure, show, legend, xlabel, ylabel

# %%
df = pd.read_csv("/home/ernestotb/Computacional/Actividad4/Datos/15Feb17.csv", names=["PRES","HGHT","TEMP", "DWPT", "RELH", "MIXR", "DRCT", "SKNT", "THTA", "THTE", "THTV"])

# %%
df.columns
# Out:
# Index(['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA',
#        'THTE', 'THTV'],
#       dtype='object')

# %%
df.PRES= pd.to_numeric(df.PRES, errors='coerce')
df.HGHT= pd.to_numeric(df.HGHT, errors='coerce')
df.TEMP= pd.to_numeric(df.TEMP, errors='coerce')
df.DWPT= pd.to_numeric(df.DWPT, errors='coerce')
df.RELH= pd.to_numeric(df.RELH, errors='coerce')
df.MIXR= pd.to_numeric(df.MIXR, errors='coerce')
df.DRCT= pd.to_numeric(df.DRCT, errors='coerce')
df.SKNT= pd.to_numeric(df.SKNT, errors='coerce')
df.THTA= pd.to_numeric(df.THTA, errors='coerce')
df.THTE= pd.to_numeric(df.THTE, errors='coerce')
df.THTV= pd.to_numeric(df.THTV, errors='coerce')

# %%
df.head()
# Out:
#      PRES    HGHT  TEMP  DWPT  RELH  MIXR   DRCT  SKNT   THTA   THTE   THTV
# 0     NaN     NaN   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 1     NaN     NaN   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 2  1000.0   205.0   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 3   925.0   855.0   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 4   881.0  1252.0   3.2  -1.0  74.0  4.05  140.0   6.0  286.5  298.3  287.2

# %%
df_cl=df.dropna()

# %%
df_cl.head(3)
# Out:
#     PRES    HGHT  TEMP  DWPT  RELH  MIXR   DRCT  SKNT   THTA   THTE   THTV
# 4  881.0  1252.0   3.2  -1.0  74.0  4.05  140.0   6.0  286.5  298.3  287.2
# 5  876.0  1299.0   4.8  -2.2  60.0  3.73  130.0   6.0  288.7  299.6  289.3
# 6  867.0  1385.0   5.4  -2.6  56.0  3.66  113.0   7.0  290.1  301.0  290.8

# %%
df.HGHT.dtypes
# Out:
# dtype('float64')

# %%
y=df_cl[u'PRES']
x=df_cl[u'HGHT']
pres=plt.plot(x,y,'b.')
pres_l=plt.plot(x,y, 'b-')
plb.title("Gráfica de altura-presión")
plb.xlabel("Altura [m]")
plb.ylabel("Presión [hPa]")
plt.grid(True)
plb.show()

# %%
y=df_cl[u'HGHT']
DWT=df_cl[u'DWPT']
pres=plt.plot(DWT,y, 'g.')
pres_l=plt.plot(DWT,y, 'g-')
plb.title("Gráfica de Punto de rocío-Altura")
plb.xlabel("Punto de rocío (DWPT) [°C]")
plb.ylabel("Altura [m]")
plt.grid(True)
plb.show()

# %%
Temp= df_cl[u'TEMP']
y= df_cl[u'HGHT']
temph=plt.plot(Temp,y, 'r.')
temph_l=plt.plot(Temp,y, 'r-')
plb.xlabel("Temperatura [°C]")
plb.ylabel("Altura (m)")
plb.title("Gráfica de Temperatura - Altura")
plt.grid(True)
plb.show()

# %%
y= df_cl[u'HGHT']
DWT=df_cl[u'DWPT']
Temp= df_cl[u'TEMP']
temps=plt.plot(Temp, y, 'r-', DWT, y, 'b--')
plb.ylabel("Altura [m]")
plb.xlabel("Tamperatura (°C)")

plt.annotate('Temperatura', xy=(-20, 6000))
plt.annotate('Punto de rocío', xy=(-80, 8000))
plb.show()

# %%
import os.path
import tephi as tph

# %%
dew_point = pd.read_csv("/home/ernestotb/Computacional/Actividad4/Datos/dew.csv", names=["PRES", "DWPT"])
dry_bulb = pd.read_csv("/home/ernestotb/Computacional/Actividad4/Datos/temp.csv", names=["PRES", "TEMP"])

tpg = tph.Tephigram()
tpg.plot(dew_point)
tpg.plot(dry_bulb)

profile.barbs(barbs)

plt.show()

# %%
dew_point = pd.read_csv("/home/ernestotb/Computacional/Actividad4/Datos/dews.csv", names=["PRES", "DWPT"])
dry_bulb = pd.read_csv("/home/ernestotb/Computacional/Actividad4/Datos/temps.csv", names=["PRES", "TEMP"])

tpg = tph.Tephigram()
tpg.plot(dew_point, label='Punto de rocío', color='blue', linewidth=1, linestyle='--')
tpg.plot(dry_bulb, label='Temperatura', color='red', linewidth=1, linestyle='-')

plt.show()
